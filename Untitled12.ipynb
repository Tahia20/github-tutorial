# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahia20/github-tutorial/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime
import random

# %%
num_base_stations = 10
num_days = 7
num_hours = num_days * 24  # Total hours of data
time_range = pd.date_range(start='2025-01-01', periods=num_hours, freq='H')
# Out:
# <ipython-input-2-166f0b91ee1e>:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   time_range = pd.date_range(start='2025-01-01', periods=num_hours, freq='H')

# %%
data = []

for bs_id in range(1, num_base_stations + 1):  # Loop through 10 base stations
    for timestamp in time_range:  # Loop through every hour in 7 days
        load = np.random.uniform(10, 100)  # Load (10% to 100%)
        esmode = np.random.choice([0, 1])  # Energy-saving mode (0 or 1)
        tx_power = np.random.uniform(10, 50)  # Transmission power (10 to 50W)

        # Energy Consumption formula (6G is 30% more efficient than 5G)
        energy_consumption = (40 + 80 * (load / 100) + 8 * esmode + 0.4 * tx_power +
                             np.random.normal(0, 5))  # Adding some noise

        # Store data
        data.append([timestamp, f'BS_{bs_id}', energy_consumption, load, esmode, tx_power])

# %%
# Column names
columns = ['Time', 'BS', 'Energy (W)', 'Load (%)', 'ESMODE', 'TXpower (W)']

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Save to CSV
df.to_csv('6G_Energy_Consumption.csv', index=False)

# Display first few rows
df.head()
# Out:
#                  Time    BS  Energy (W)   Load (%)  ESMODE  TXpower (W)
# 0 2025-01-01 00:00:00  BS_1  123.047397  87.699650       0    37.629535
# 1 2025-01-01 01:00:00  BS_1  126.938050  86.806754       0    46.962588
# 2 2025-01-01 02:00:00  BS_1   70.958360  21.249756       1    13.917849
# 3 2025-01-01 03:00:00  BS_1   77.588896  37.420356       0    15.110679
# 4 2025-01-01 04:00:00  BS_1   94.424173  43.735258       0    46.709193
